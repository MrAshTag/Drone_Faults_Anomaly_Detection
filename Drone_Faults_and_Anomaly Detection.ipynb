# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from pylab import *
import seaborn as sns
# %matplotlib inline
import statsmodels.stats.api as sm
import statsmodels.stats.api as sms 
from scipy.stats import boxcox

# %% [markdown]
# ### I. Importing Data

# %% [markdown]
# ##### 1. Importing data for engine failure category to label it as instances where there was engine failure anomaly

# %%
# uploading data for engine failure
df_engine_fail1 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-18-15-53-31_1_engine_failure/carbonZ_2018-07-18-15-53-31_1_engine_failure-diagnostics.csv')
df_engine_fail2 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-18-15-53-31_2_engine_failure/carbonZ_2018-07-18-15-53-31_2_engine_failure-diagnostics.csv')
df_engine_fail3 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-30-16-39-00_1_engine_failure/carbonZ_2018-07-30-16-39-00_1_engine_failure-diagnostics.csv')
df_engine_fail4 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-30-16-39-00_2_engine_failure/carbonZ_2018-07-30-16-39-00_2_engine_failure-diagnostics.csv')
df_engine_fail5 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-11-56-30_engine_failure/carbonZ_2018-09-11-11-56-30_engine_failure-diagnostics.csv')
df_engine_fail6 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-14-22-07_1_engine_failure/carbonZ_2018-09-11-14-22-07_1_engine_failure-diagnostics.csv')
df_engine_fail7 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-14-22-07_2_engine_failure/carbonZ_2018-09-11-14-22-07_2_engine_failure-diagnostics.csv')

# %% [markdown]
# ##### 2. Importing data for no failure, in order to label as instance where there were no faults dectect and the drones flew well.

# %%
#Importing more data for no failures
df_10 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-18-16-37-39_1_no_failure/carbonZ_2018-07-18-16-37-39_1_no_failure-diagnostics.csv')
df_11 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-30-16-39-00_3_no_failure/carbonZ_2018-07-30-16-39-00_3_no_failure-diagnostics.csv')
df_12 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-14-16-55_no_failure/carbonZ_2018-09-11-14-16-55_no_failure-diagnostics.csv')
df_13 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-14-41-38_no_failure/carbonZ_2018-09-11-14-41-38_no_failure-diagnostics.csv')
df_14 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-15-05-11_2_no_failure/carbonZ_2018-09-11-15-05-11_2_no_failure-diagnostics.csv')
df_15 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-05-14-34-20_1_no_failure/carbonZ_2018-10-05-14-34-20_1_no_failure-diagnostics.csv')
#df_16 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-05-14-37-22_1_no_failure/carbonZ_2018-10-05-14-37-22_1_no_failure-diagnostics.csv')
df_17 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-05-15-52-12_1_no_failure/carbonZ_2018-10-05-15-52-12_1_no_failure-diagnostics.csv')
df_18 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-05-15-52-12_2_no_failure/carbonZ_2018-10-05-15-52-12_2_no_failure-diagnostics.csv')
df_19 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-18-11-08-24_no_failure/carbonZ_2018-10-18-11-08-24_no_failure-diagnostics.csv')

# %% [markdown]
# ##### 3. Importing data for no-ground thruth, in order to label it

# %%
# Uploading new data for No-ground thruth
df_20 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-18-12-10-11_no_ground_truth/carbonZ_2018-07-18-12-10-11_no_ground_truth-diagnostics.csv')

# %% [markdown]
# ##### 4. Importing data for elevator failure instances, to be labeled as "elevator failure"

# %%
# uploading new data for elevator failure
df_21 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-14-41-51_elevator_failure/carbonZ_2018-09-11-14-41-51_elevator_failure-diagnostics.csv')
df_22 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-15-05-11_1_elevator_failure/carbonZ_2018-09-11-15-05-11_1_elevator_failure-diagnostics.csv')

# %% [markdown]
# ##### 5. Importing data for rudder right failure instances, to be labeled as such.

# %%
# Uploading new data for rudder right failure
df_23 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-15-06-34_1_rudder_right_failure/carbonZ_2018-09-11-15-06-34_1_rudder_right_failure-diagnostics.csv')
df_24 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-15-06-34_2_rudder_right_failure/carbonZ_2018-09-11-15-06-34_2_rudder_right_failure-diagnostics.csv')

# %% [markdown]
# ##### 6. Importing data for rudder left failure instance. We're going to label these instances

# %%
# Uploading new data for rudder left failure
df_25 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-15-06-34_3_rudder_left_failure/carbonZ_2018-09-11-15-06-34_3_rudder_left_failure-diagnostics.csv')

# %% [markdown]
# ##### 7. Importing data for engine failure with emergency trajectory, we're groing to label theses instances too.

# %%
#Uploading new data for engine failure with emr traj
df_26 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-18-16-22-01_engine_failure_with_emr_traj/carbonZ_2018-07-18-16-22-01_engine_failure_with_emr_traj-diagnostics.csv')
df_27 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-18-16-37-39_2_engine_failure_with_emr_traj/carbonZ_2018-07-18-16-37-39_2_engine_failure_with_emr_traj-diagnostics.csv')
df_28 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-30-16-29-45_engine_failure_with_emr_traj/carbonZ_2018-07-30-16-29-45_engine_failure_with_emr_traj-diagnostics.csv')
df_29 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-30-17-10-45_engine_failure_with_emr_traj/carbonZ_2018-07-30-17-10-45_engine_failure_with_emr_traj-diagnostics.csv')
df_30 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-30-17-20-01_engine_failure_with_emr_traj/carbonZ_2018-07-30-17-20-01_engine_failure_with_emr_traj-diagnostics.csv')
df_31 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-30-17-36-35_engine_failure_with_emr_traj/carbonZ_2018-07-30-17-36-35_engine_failure_with_emr_traj-diagnostics.csv')
df_32 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-30-17-46-31_engine_failure_with_emr_traj/carbonZ_2018-07-30-17-46-31_engine_failure_with_emr_traj-diagnostics.csv')
df_33 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-05-15-52-12_3_engine_failure_with_emr_traj/carbonZ_2018-10-05-15-52-12_3_engine_failure_with_emr_traj-diagnostics.csv')
df_34 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-05-15-55-10_engine_failure_with_emr_traj/carbonZ_2018-10-05-15-55-10_engine_failure_with_emr_traj-diagnostics.csv')
df_35 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-05-16-04-46_engine_failure_with_emr_traj/carbonZ_2018-10-05-16-04-46_engine_failure_with_emr_traj-diagnostics.csv')
df_36 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-18-11-03-57_engine_failure_with_emr_traj/carbonZ_2018-10-18-11-03-57_engine_failure_with_emr_traj-diagnostics.csv')
df_37 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-18-11-04-00_engine_failure_with_emr_traj/carbonZ_2018-10-18-11-04-00_engine_failure_with_emr_traj-diagnostics.csv')
df_38 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-18-11-04-08_1_engine_failure_with_emr_traj/carbonZ_2018-10-18-11-04-08_1_engine_failure_with_emr_traj-diagnostics.csv')
df_39 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-18-11-04-08_2_engine_failure_with_emr_traj/carbonZ_2018-10-18-11-04-08_2_engine_failure_with_emr_traj-diagnostics.csv')
df_40 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-18-11-04-35_engine_failure_with_emr_traj/carbonZ_2018-10-18-11-04-35_engine_failure_with_emr_traj-diagnostics.csv')
df_41 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-18-11-06-06_engine_failure_with_emr_traj/carbonZ_2018-10-18-11-06-06_engine_failure_with_emr_traj-diagnostics.csv')
df_42 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-30-17-46-31_engine_failure_with_emr_traj/carbonZ_2018-07-30-17-46-31_engine_failure_with_emr_traj-diagnostics.csv')
df_43 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-07-30-17-46-31_engine_failure_with_emr_traj/carbonZ_2018-07-30-17-46-31_engine_failure_with_emr_traj-diagnostics.csv')

# %% [markdown]
# ##### 8. Importing data for left aileron right aileron failure, we're going to label these instances.

# %%
#Uploading new data for left aileron_right_aileron_failure
df_44 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-14-52-54_left_aileron__right_aileron__failure/carbonZ_2018-09-11-14-52-54_left_aileron__right_aileron__failure-diagnostics.csv')

# %% [markdown]
# ##### 9. Importing data for rudder zero left aileron failure, we're also going to label each instance

# %%
#Uploading new data for rudder_zero__left_aileron_failure
df_45 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-17-27-13_1_rudder_zero__left_aileron_failure/carbonZ_2018-09-11-17-27-13_1_rudder_zero__left_aileron_failure-diagnostics.csv')

# %% [markdown]
# ##### 10. Importing data for both aileron failure, in order to label each instance

# %%
# Uploading new data for both_aileron_failure
df_46 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-17-27-13_2_both_ailerons_failure/carbonZ_2018-09-11-17-27-13_2_both_ailerons_failure-diagnostics.csv')

# %% [markdown]
# ##### 11. Importing data for right aileron failure, we're going to label each instance

# %%
# Uploading new data for right_aileron_failure
df_47 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-17-55-30_1_right_aileron_failure/carbonZ_2018-09-11-17-55-30_1_right_aileron_failure-diagnostics.csv')
df_48 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-05-14-37-22_2_right_aileron_failure/carbonZ_2018-10-05-14-37-22_2_right_aileron_failure-diagnostics.csv')

# %% [markdown]
# ##### 12. Importing data for left aileron failure, we're going to label each instance in these datasets

# %%
# Uploading new data for left_aileron_failure
df_49 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-09-11-17-55-30_2_left_aileron_failure/carbonZ_2018-09-11-17-55-30_2_left_aileron_failure-diagnostics.csv')
df_50 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-05-14-37-22_3_left_aileron_failure/carbonZ_2018-10-05-14-37-22_3_left_aileron_failure-diagnostics.csv')

# %% [markdown]
# ##### 13. Importing data for right aileron failure with emergency trajectory, to be labeled

# %%
# Uploading new data foe right_aileron_failure_with_emr_traj
df_51 = pd.read_csv(r'/Users/bekimbaya/Downloads/12707963/processed/carbonZ_2018-10-05-14-34-20_2_right_aileron_failure_with_emr_traj/carbonZ_2018-10-05-14-34-20_2_right_aileron_failure_with_emr_traj-diagnostics.csv')

# %% [markdown]
# ### II. Data Wrangling

# %% [markdown]
# ##### 1. We're going to append all datasets related to engine failure together into one dataset related for engine failure

# %%
#Appending the datasets together
engine_failureDF1 = pd.concat([df_engine_fail1, df_engine_fail2])
engine_failureDF2 = pd.concat([df_engine_fail3, df_engine_fail4])
engine_failureDF3 = pd.concat([df_engine_fail5, df_engine_fail7])
engine_failureDF = pd.concat([engine_failureDF1, engine_failureDF2])
engine_failureDF = pd.concat([engine_failureDF, engine_failureDF3])
engine_failureDF = pd.concat([engine_failureDF, df_engine_fail7])

# %% [markdown]
# ###### adding a column into the principal engine failure dataset, in order to add a label in that colum for all occurences in that dataset

# %%
# Adding a classification column for engine failure
engine_failureDF['outcome'] = "engine failure"

# %% [markdown]
# ##### 2. Appending all dataset related to instances where there were no failures.

# %%
no_failureDF1 = pd.concat([df_10, df_11])
no_failureDF2 = pd.concat([df_12, df_13])
no_failureDF3 = pd.concat([df_14, df_15])
no_failureDF4 = pd.concat([df_17, df_18])
#no_failureDF5 = pd.concat([df_18, df_19])

no_failureDF = pd.concat([no_failureDF1, no_failureDF2])
no_failureDF = pd.concat([no_failureDF3, no_failureDF4])
no_failureDF = pd.concat([no_failureDF, df_engine_fail19])

# %% [markdown]
# ###### Adding a column to the principal dataset for no failures, and writting a label in that column

# %%
# Adding a classification column to the dataset of no failures
no_failureDF['outcome'] = "no failure"

# %% [markdown]
# ##### 3. Adding a column for classification for no ground truth dataset, there is only one dataset for this category

# %%
#Adding a classification column for no ground truth
df_20['outcome'] = "no ground truth"
noGroundT_DF = df_20

# %% [markdown]
# ##### 4. Appending all datasets in the elevator failure category datasets and adding a column to the principal data of this category and inputing the label

# %%
# appending all elevator failure datasets
elevFailDF = pd.concat([df_21, df_22])
# Adding a classification column
elevFailDF['outcome'] = "elevator failure"

# %% [markdown]
# ##### 5. Appending all datasets in the rudder right failure category and adding a column to the principal data of this category and inputing a label

# %%
# Appending all the rudder right failure datasets
rudderR_DF = pd.concat([df_23, df_24])
# Adding a classification column
rudderR_DF['outcome'] = "rudder right failure"

# %% [markdown]
# ##### 6. There is only one dataset in the rudder left failure category, so we're going to add a classification column to this dataset and add a label

# %%
#Adding classification column for rudder left failure
rudderL_DF = df_25
rudderL_DF['outcome'] = "rudder left failure"

# %% [markdown]
# ##### 7. Appending all datasets in the engine failure with emergency trajectory category into one principal dataset for this category, then adding a column to the principal dataset for labeling

# %%
# Appending dataset for engine failure with emr traj
df_26  = pd.concat([df_26, df_27])
df_28 = pd.concat([df_28, df_29])
df_30 = pd.concat([df_30, df_31])
df_32 = pd.concat([df_32, df_33])
df_34 = pd.concat([df_34, df_35])
df_36 = pd.concat([df_36, df_37])
df_38 = pd.concat([df_38, df_39])
df_40 = pd.concat([df_40, df_41])
df_42 = pd.concat([df_42, df_43])

df_26 = pd.concat([df_26, df_28])
df_30 = pd.concat([df_30, df_32])
df_34 = pd.concat([df_34, df_36])
df_38 = pd.concat([df_38, df_40])
df_38 = pd.concat([df_38, df_42])

df_26 = pd.concat([df_26, df_30])
df_34 = pd.concat([df_34, df_38])

engineFail_emrTraj_DF = pd.concat([df_26, df_34])

# Adding a classification column for the fault
engineFail_emrTraj_DF['outcome'] = "engine failure with emr traj"

# %% [markdown]
# ##### 8. There is only one dataset for left aileron right aileron failure category, so we're going to add a column to this dataset for classification

# %%
# Adding a classification columns for the left aileron_right_aileron_failure 
leftAil_rightAilF_DF = df_44
leftAil_rightAilF_DF['outcome'] = "left aileron right aileron failure"

# %% [markdown]
# ##### 9. Adding a classification column to the dataset for rudder zero left aileron failure category, there is only on dataset for this category

# %%
# Adding a classification columns for the rudder_zero__left_aileron_failure
rudderZ_leftAil_DF = df_45
rudderZ_leftAil_DF['outcome'] = "rudder zero left aileron failure"

# %% [markdown]
# ##### 10. Adding a column to the dataset for both aileron failure category, there is only one dataset in this category

# %%
# Adding a classification column for both_aileron_failure
bothAilDF = df_46
bothAilDF['outcome'] = "both aileron failure"

# %% [markdown]
# ##### 11. Appending all the datasets in the right aileron failure category, then adding a column to the principal dataset for classification label

# %%
# Appending the dataset for right_aileron_failure
rightAilDF = pd.concat([df_47, df_48])
# Classification column 
rightAilDF['outcome'] = "right aileron failure"

# %% [markdown]
# ##### 12. Appending all datasets in the left aileron failure category, then adding a column to the principal dataset for the classfication of each instance

# %%
# Appending the dataset for left_aileron_failure
leftAilDF = pd.concat([df_49, df_50])
# Adding a classification column
leftAilDF['outcome'] = "left aileron failure"

# %% [markdown]
# ##### 13. Appending all the different principal datasets from each category into one general dataframe

# %%
# Appending all the datasets into one principal dataset
drone_diagnostics = pd.concat([engine_failureDF, no_failureDF])

noGroundT_DF = pd.concat([noGroundT_DF, elevFailDF])
rudderR_DF = pd.concat([rudderR_DF, rudderL_DF])
engineFail_emrTraj_DF = pd.concat([engineFail_emrTraj_DF, leftAil_rightAilF_DF])
rudderZ_leftAil_DF = pd.concat([rudderZ_leftAil_DF, bothAilDF])
rightAilDF = pd.concat([rightAilDF, leftAilDF])

noGroundT_DF = pd.concat([noGroundT_DF, rudderR_DF])
engineFail_emrTraj_DF = pd.concat([engineFail_emrTraj_DF,rudderZ_leftAil_DF])
engineFail_emrTraj_DF = pd.concat([engineFail_emrTraj_DF, rightAilDF])

drone_diagnostics = pd.concat([drone_diagnostics, noGroundT_DF])
drone_diagnostics = pd.concat([drone_diagnostics, engineFail_emrTraj_DF, ])

# %%
#To display all the columns
pd.set_option('display.max_columns', None)

# %%
# Viewing the new dataset
drone_diagnostics.head(4)
# Out:
#                  %time  field.header.seq   field.header.stamp  \
# 0  1531943812200457430               202  1531943812200143162
# 1  1531943813701107846               203  1531943813700431279
# 2  1531943815200546499               204  1531943815199948138
# 3  1531943816200859738               205  1531943816200007716
#
#    field.header.frame_id  field.status0.level      field.status0.name  \
# 0                    NaN                    0  mavros: FCU connection
# 1                    NaN                    0  mavros: FCU connection
# 2                    NaN                    0  mavros: FCU connection
# 3                    NaN                    0  mavros: FCU connection
#
#   field.status0.message    field.status0.hardware_id  \
# 0             connected  udp://127.0.0.1:14551@14555
# 1             connected  udp://127.0.0.1:14551@14555
# 2             connected  udp://127.0.0.1:14551@14555
# 3             connected  udp://127.0.0.1:14551@14555
#
# ...

# %% [markdown]
# #### 14. Cleaning a rearranging the principal dataset, to get rid of wierd column names and rename new column

# %% [markdown]
# ##### adding all weird column name to a list

# %%
keep = ['field.header.seq', 'field.status0.name','field.status0.message',
        'field.status0.values0.key', 'field.status0.values0.value','field.status0.values1.key','field.status0.values1.value',
        'field.status0.values2.key', 'field.status0.values2.value','field.status0.values3.key','field.status0.values3.value',
        'field.status0.values4.key', 'field.status0.values4.value','field.status0.values5.key', 'field.status0.values5.value',
        'field.status0.values6.key', 'field.status0.values6.value','field.status0.values7.key', 'field.status0.values7.value',
        'field.status0.values8.key', 'field.status0.values8.value','field.status0.values9.key', 'field.status0.values9.value',
        'field.status1.name', 'field.status1.message','field.status1.values0.key', 'field.status1.values0.value',
        'field.status1.values1.key','field.status1.values1.value','field.status1.values2.key','field.status1.values2.value',
        'field.status1.values3.key','field.status1.values3.value', 'field.status2.name','field.status2.message',
        'field.status2.values0.key', 'field.status2.values0.value', 'field.status2.values1.key','field.status2.values1.value',
        'field.status2.values2.key', 'field.status2.values2.value', 'field.status2.values3.key', 'field.status2.values3.value',
        'field.status2.values4.key', 'field.status2.values4.value', 'field.status2.values5.key', 'field.status2.values5.value',
        'field.status3.name','field.status3.message', 'field.status3.values0.key', 'field.status3.values0.value',
        'field.status3.values1.key', 'field.status3.values1.value', 'field.status3.values2.key', 'field.status3.values2.value',
        'field.status3.values3.key', 'field.status3.values3.value', 'field.status3.values4.key', 'field.status3.values4.value',
        'field.status3.values5.key', 'field.status3.values5.value', 'field.status3.values6.key', 'field.status3.values6.value',
        'field.status3.values7.key', 'field.status3.values7.value', 'field.status3.values8.key', 'field.status3.values8.value',
        'field.status3.values9.key', 'field.status3.values9.value', 'field.status3.values10.key', 'field.status3.values10.value',
        'field.status3.values11.key', 'field.status3.values11.value', 'field.status3.values12.key', 'field.status3.values12.value',
        'field.status3.values13.key', 'field.status3.values13.value', 'field.status3.values14.key', 'field.status3.values14.value',
        'field.status3.values15.key', 'field.status3.values15.value', 'field.status3.values16.key', 'field.status3.values16.value',
        'field.status3.values17.key', 'field.status3.values17.value', 'field.status3.values18.key', 'field.status3.values18.value',
        'field.status3.values19.key', 'field.status3.values19.value', 'field.status3.values20.key' , 'field.status3.values20.value',
        'field.status3.values21.key', 'field.status3.values21.value', 'field.status3.values22.key', 'field.status3.values22.value',
        'field.status3.values23.key', 'field.status3.values23.value', 'field.status3.values24.key', 'field.status3.values24.value',
        'field.status3.values25.key', 'field.status3.values25.value','field.status4.name', 'field.status4.message',
        'field.status4.values0.key', 'field.status4.values0.value','field.status4.values1.key','field.status4.values1.value',
        'field.status4.values2.key', 'field.status4.values2.value', 'outcome'
       ]

# %% [markdown]
# ##### Renaming the columns

# %%
#Creating a subset with the dataset
drone_diagnostics2 = drone_diagnostics[keep]

# %% [markdown]
# ###### Renaming the columns into a new version of the general dataset

# %%
drone_diagnostics2.rename(columns = {'field.status0.message' : 'FCU connection'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status0.values0.value' : 'Received packets'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status0.values1.value' : 'Dropped packets'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status0.values2.value' : 'Buffer overruns'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status0.values3.value' : 'Parse errors'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status0.values4.value' : 'Rx sequence number'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status0.values5.value' : 'Tx sequence number'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status0.values6.value' : 'Rx total bytes'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status0.values7.value' : 'Tx total bytes'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status0.values8.value' : 'Rx speed'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status0.values9.value' : 'Tx speed'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status1.message' : 'mavros: GPS'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status1.values0.value' : 'Satellites visible'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status1.values1.value' : 'Fix type'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status1.values2.value' : 'EPH (m)'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status1.values3.value' : 'EPV (m)'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status2.message' : 'mavros: Heartbeat'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status2.values0.value' : 'Heartbeats since startup'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status2.values1.value' : 'Frequency (Hz)'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status2.values2.value' : 'Vehicle type'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status2.values3.value' : 'Autopilot type'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status2.values4.value' : 'Mode'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status2.values5.value' : 'System status'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.message' : 'mavros: System'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values0.value' : 'Sensor present'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values1.value' : 'Sensor enabled'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values2.value' : 'Sensor helth'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values3.value' : '3D gyro'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values4.value' : '3D accelerometer'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values5.value' : '3D magnetometer'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values6.value' : 'absolute pressure'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values7.value' : 'differential pressure'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values8.value' : 'GPS'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values9.value' : '3D angular rate control'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values10.value' : 'attitude stabilization'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values11.value' : 'yaw position'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values12.value' : 'z/altitude control'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values13.value' : 'x/y position control'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values14.value' : 'motor outputs / control'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values15.value' : 'rc receiver'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values16.value' : 'AHRS subsystem health'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values17.value' : 'Terrain subsystem health'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values18.value' : 'Logging'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values19.value' : 'CPU Load (%)'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values20.value' : 'Drop rate (%)'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values21.value' : 'Errors comm'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values22.value' : 'Errors count #1'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values23.value' : 'Errors count #2'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values24.value' : 'Errors count #3'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status3.values25.value' : 'Errors count #4'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status4.message' : 'mavros: Battery'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status4.values0.value' : 'Voltage'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status4.values1.value' : 'Current'}, inplace=True)
drone_diagnostics2.rename(columns = {'field.status4.values2.value' : 'Remaining'}, inplace=True)
# Out:
# /Users/bekimbaya/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
#Viewing the 2nd version of the dataset
drone_diagnostics2.head(3)
# Out:
#    field.header.seq      field.status0.name FCU connection  \
# 0               202  mavros: FCU connection      connected
# 1               203  mavros: FCU connection      connected
# 2               204  mavros: FCU connection      connected
#
#   field.status0.values0.key  Received packets field.status0.values1.key  \
# 0         Received packets:             44424          Dropped packets:
# 1         Received packets:             44710          Dropped packets:
# 2         Received packets:             45010          Dropped packets:
#
#    Dropped packets field.status0.values2.key  Buffer overruns  \
# 0                0          Buffer overruns:                0
# 1                0          Buffer overruns:                0
# 2                0          Buffer overruns:                0
#
#   field.status0.values3.key  Parse errors field.status0.values4.key  \
# 0             Parse errors:             0       Rx sequence number:
# ...

# %% [markdown]
# ##### Makinga list of new names of columns to keep, excluding weird unnecessary column names

# %%
# Another list of column names to keep
keep2 = ['field.header.seq', 'FCU connection','Received packets','Dropped packets',
         'Buffer overruns', 'Parse errors', 'Rx sequence number', 'Tx sequence number',
         'Rx total bytes', 'Tx total bytes', 'Rx speed', 'Tx speed', 'mavros: GPS', 'Satellites visible',
         'Fix type', 'EPV (m)', 'mavros: Heartbeat', 'Heartbeats since startup', 'Frequency (Hz)',
         'Vehicle type', 'Autopilot type', 'Mode', 'System status', 'mavros: System', 'Sensor present',
         'Sensor enabled', 'Sensor helth', '3D gyro', '3D accelerometer', '3D magnetometer', 'absolute pressure',
         'differential pressure', 'GPS', '3D angular rate control', 'attitude stabilization', 'yaw position',
         'z/altitude control', 'x/y position control', 'motor outputs / control', 'rc receiver', 'AHRS subsystem health',
         'Terrain subsystem health', 'Logging', 'CPU Load (%)', 'Drop rate (%)', 'Errors comm',
         'Errors count #1', 'Errors count #2', 'Errors count #3', 'Errors count #4', 'mavros: Battery',
         'Voltage', 'Current', 'Remaining', 'outcome'
        ]

# %% [markdown]
# ###### Here are all the columns currently  in the dataset

# %%
list(drone_diagnostics2)
# Out:
# ['field.header.seq',
#  'field.status0.name',
#  'FCU connection',
#  'field.status0.values0.key',
#  'Received packets',
#  'field.status0.values1.key',
#  'Dropped packets',
#  'field.status0.values2.key',
#  'Buffer overruns',
#  'field.status0.values3.key',
#  'Parse errors',
#  'field.status0.values4.key',
#  'Rx sequence number',
#  'field.status0.values5.key',
#  'Tx sequence number',
#  'field.status0.values6.key',
#  'Rx total bytes',
#  'field.status0.values7.key',
#  'Tx total bytes',
#  'field.status0.values8.key',
#  'Rx speed',
#  'field.status0.values9.key',
#  'Tx speed',
#  'field.status1.name',
#  'mavros: GPS',
#  'field.status1.values0.key',
#  'Satellites visible',
#  'field.status1.values1.key',
#  'Fix type',
#  'field.status1.values2.key',
#  'EPH (m)',
#  'field.status1.values3.key',
#  'EPV (m)',
#  'field.status2.name',
#  'mavros: Heartbeat',
#  'field.status2.values0.key',
#  'Heartbeats since startup',
#  'field.status2.values1.key',
# ...

# %% [markdown]
# ##### Excluding weild name and keeping only clean names in a newer version of the general dataset of drone diagnostics data

# %%
# Creating a newer dataset with new column names
drone_diagnostics3 = drone_diagnostics2[keep2]

# %%
# Viewing the new version of the dataset
drone_diagnostics3.head(1)
# Out:
#    field.header.seq FCU connection  Received packets  Dropped packets  \
# 0               202      connected             44424                0
#
#    Buffer overruns  Parse errors  Rx sequence number  Tx sequence number  \
# 0                0             0                 215                  82
#
#    Rx total bytes  Tx total bytes  Rx speed  Tx speed mavros: GPS  \
# 0         1216099            9425    8831.0    3552.0      3D fix
#
#    Satellites visible  Fix type  EPV (m) mavros: Heartbeat  \
# 0                  16         4     1.16            Normal
#
#    Heartbeats since startup  Frequency (Hz)         Vehicle type  \
# 0                       259        0.999973  Fixed wing aircraft
#
#                Autopilot type    Mode System status mavros: System  \
# 0  ArduPilotMega / ArduCopter  GUIDED        Active         Normal
#
#   Sensor present Sensor enabled Sensor helth 3D gyro 3D accelerometer  \
# ...

# %% [markdown]
# ###### Here are all the remaining columns in the newer version of the general dataset

# %%
list(drone_diagnostics3)
# Out:
# ['field.header.seq',
#  'FCU connection',
#  'Received packets',
#  'Dropped packets',
#  'Buffer overruns',
#  'Parse errors',
#  'Rx sequence number',
#  'Tx sequence number',
#  'Rx total bytes',
#  'Tx total bytes',
#  'Rx speed',
#  'Tx speed',
#  'mavros: GPS',
#  'Satellites visible',
#  'Fix type',
#  'EPV (m)',
#  'mavros: Heartbeat',
#  'Heartbeats since startup',
#  'Frequency (Hz)',
#  'Vehicle type',
#  'Autopilot type',
#  'Mode',
#  'System status',
#  'mavros: System',
#  'Sensor present',
#  'Sensor enabled',
#  'Sensor helth',
#  '3D gyro',
#  '3D accelerometer',
#  '3D magnetometer',
#  'absolute pressure',
#  'differential pressure',
#  'GPS',
#  '3D angular rate control',
#  'attitude stabilization',
#  'yaw position',
#  'z/altitude control',
#  'x/y position control',
#  'motor outputs / control',
#  'rc receiver',
#  'AHRS subsystem health',
#  'Terrain subsystem health',
#  'Logging',
#  'CPU Load (%)',
#  'Drop rate (%)',
#  'Errors comm',
# ...

# %% [markdown]
# #### 15. Creating Recoding Functions to be Used on Categorical variables

# %%
#function to recode heatbeat column
def heartbeatRec(series):
    if series == "Normal":
        return 1
    else:
        return 0

# %%
#Function to recode accelerometer column
def accelRec(series):
    if series == "Ok":
        return 1
    else:
        return 0

# %%
#Function to recode magnetometer column
def magnetoRec(series):
    if series == "Ok":
        return 1
    else:
        return 0

# %%
#Function to recode absolute pressure column
def absPreRec(series):
    if series == "Ok":
        return 1
    else:
        return 0

# %%
#Function to recode differential pressure column
def diffPressRec(series):
    if series =="Ok":
        return 1
    else:
        return 0

# %%
#Function to recode GPS column
def gpsRec(series):
    if series == "Ok":
        return 1
    else:
        return 0

# %%
# Function to recode 3D angular rate control column
def _3d_angu_Rec(series):
    if series == "Ok":
        return 1
    else:
        return 0

# %%
#Function to recode attitude stabilization	column
def attStaRec(series):
    if series == "Ok":
        return 1
    else:
        return 0

# %%
#Function to recode yaw position column
def yawPosRec(series):
    if series == "Ok":
        return 1
    else:
        return 0

# %%
#Function to recode z/altitude control	column
def zaltitudeRec(series):
    if series == "Ok":
        return 1
    else:
        return 0

# %%
# Function to recode xyposition column
def xyPositionRec(series):
    if series == "Ok":
        return 1
    else:
        return 0

# %%
# Function to recode motor outputs / control column
def motorOutputRec(series):
    if series == "Ok":
        return 1
    else:
        return 0

# %%
# Function to recode rc receiver column
def rcReceiveRec(series):
    if series == "Ok":
        return 1
    else:
        return 0

# %%
# Function to recode AHRS subsystem health	column
def ahrsSybs_Rec(series):
    if series == "Ok":
        return 1
    else:
        return 0

# %%
# Function to recode Terrain subsystem health column
def terrSubRec(series):
    if series == "Ok":
        return 1
    else:
        return 0

# %%
#Function to recode the Logging column
def Logging(series):
    if series == "Ok":
        return 1
    else:
        return 0

# %%
# Function to recode mavros: Battery column
def batteryRec(series):
    if series == "Low voltage":
        return 1
    if series == "High voltage":
        return 3
    else:
        return 2

# %% [markdown]
# ##### Using the functions below to recode categorical variables into new variables

# %%
drone_diagnostics3['mavros: Heartbeat_Rec'] = (drone_diagnostics3['mavros: Heartbeat']).apply(heartbeatRec)
drone_diagnostics3['3D accelerometer_Rec'] = (drone_diagnostics3['3D accelerometer']).apply(accelRec)
drone_diagnostics3['3D magnetometer_Rec'] = (drone_diagnostics3['3D magnetometer']).apply(magnetoRec)
drone_diagnostics3['absolute pressure_Rec'] = (drone_diagnostics3['absolute pressure']).apply(absPreRec)
drone_diagnostics3['differential pressure_Rec'] = (drone_diagnostics3['differential pressure']).apply(diffPressRec)
drone_diagnostics3['GPS_Rec'] = (drone_diagnostics3['GPS']).apply(gpsRec)
drone_diagnostics3['3D angular rate control_Rec'] = (drone_diagnostics3['3D angular rate control']).apply(_3d_angu_Rec)
drone_diagnostics3['attitude stabilization_Rec'] = (drone_diagnostics3['attitude stabilization']).apply(attStaRec)
drone_diagnostics3['yaw position_Rec'] = (drone_diagnostics3['yaw position']).apply(yawPosRec)
drone_diagnostics3['z/altitude control_Rec'] = (drone_diagnostics3['z/altitude control']).apply(zaltitudeRec)
drone_diagnostics3['x/y position control_Rec'] = (drone_diagnostics3['x/y position control']).apply(xyPositionRec)
drone_diagnostics3['motor outputs / control_Rec'] = (drone_diagnostics3['motor outputs / control']).apply(motorOutputRec)
drone_diagnostics3['rc receiver_Rec'] = (drone_diagnostics3['rc receiver']).apply(rcReceiveRec)
drone_diagnostics3['AHRS subsystem health_Rec'] = (drone_diagnostics3['AHRS subsystem health']).apply(ahrsSybs_Rec)
drone_diagnostics3['Terrain subsystem health_Rec'] = (drone_diagnostics3['Terrain subsystem health']).apply(terrSubRec)
drone_diagnostics3['Logging_Rec'] = (drone_diagnostics3['Logging']).apply(Logging)
drone_diagnostics3['mavros: Battery_Rec'] = (drone_diagnostics3['mavros: Battery']).apply(batteryRec)
# Out:
# <ipython-input-174-2a26e693dfab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drone_diagnostics3['mavros: Heartbeat_Rec'] = (drone_diagnostics3['mavros: Heartbeat']).apply(heartbeatRec)
# <ipython-input-174-2a26e693dfab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drone_diagnostics3['3D accelerometer_Rec'] = (drone_diagnostics3['3D accelerometer']).apply(accelRec)
# <ipython-input-174-2a26e693dfab>:3: SettingWithCopyWarning:
# ...

# %%
#Viewing the dataset to see all the recoded variables
drone_diagnostics3.head(2)
# Out:
#    field.header.seq FCU connection  Received packets  Dropped packets  \
# 0               202      connected             44424                0
# 1               203      connected             44710                0
#
#    Buffer overruns  Parse errors  Rx sequence number  Tx sequence number  \
# 0                0             0                 215                  82
# 1                0             0                 241                 158
#
#    Rx total bytes  Tx total bytes  Rx speed  Tx speed mavros: GPS  \
# 0         1216099            9425    8831.0    3552.0      3D fix
# 1         1224410           14321    8311.0    4896.0      3D fix
#
#    Satellites visible  Fix type  EPV (m) mavros: Heartbeat  \
# 0                  16         4     1.16            Normal
# 1                  18         4     1.10            Normal
#
#    Heartbeats since startup  Frequency (Hz)         Vehicle type  \
# 0                       259        0.999973  Fixed wing aircraft
# ...

# %% [markdown]
# ### III. Data Exploration

# %% [markdown]
# ##### 1. Creating a data subset for all original continuous variables

# %%
# A data subset of continuous variables
drone_diag = drone_diagnostics3[['Received packets','Rx sequence number','Tx sequence number',
                                 'Rx total bytes','Tx total bytes', 'Rx speed', 'Tx speed',
                                 'Satellites visible', 'Fix type', 'EPV (m)', 'Heartbeats since startup',
                                'Frequency (Hz)', 'CPU Load (%)']]

# %% [markdown]
# ##### 2. Creating a correlation matrix of all non empty continous variables

# %%
# Correlation Matrix
drone_matrix = drone_diag.corr()

# %%
drone_matrix
# Out:
#                           Received packets  Rx sequence number  \
# Received packets                  1.000000           -0.007926
# Rx sequence number               -0.007926            1.000000
# Tx sequence number                0.014381           -0.000760
# Rx total bytes                   -0.048307            0.012415
# Tx total bytes                   -0.083038           -0.028025
# Rx speed                         -0.006133           -0.005925
# Tx speed                          0.025525            0.018243
# Satellites visible                0.048586           -0.013650
# Fix type                         -0.017638           -0.030847
# EPV (m)                          -0.033071            0.025672
# Heartbeats since startup         -0.036122            0.014164
# Frequency (Hz)                   -0.003446            0.010330
# CPU Load (%)                      0.110403           -0.033398
#
#                           Tx sequence number  Rx total bytes  Tx total bytes  \
# ...

# %% [markdown]
# ##### 3. Visualzing the correllation matrix

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(drone_matrix, annot=True)
plt.show()

# %% [markdown]
# ##### 4. Creating a heatmap of the Correllation matrix

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(drone_matrix.corr(), annot = True, fmt='.2g',cmap= 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 5. Building a scatter plot matrix

# %%
# Importing the appropriate library
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

#plt.subplots(figsize=(20,15))
scatter_matrix(drone_diag, figsize=(20, 20))
plt.show()

# %% [markdown]
# ###### correlations worth noting:
#
# - Tx speed & Rx speed : 0.655897
# - Rx total bytes & Tx total bytes : 0.492324
# - Rx total bytes & Tx speed : -0.226109
# - Satellites visible & EPV(m) : - 0.489533
# - Rx total bytes & EPV(m) : 0.257140
# - Tx total bytes & EPV(m) : 0.215674
# - EPV(m) & Heartbeats since startup : 0.235179
# - Tx speed & heartbeats since startup : -0.195651
# - Tx total bytes & heartbeats since startup : 0.519164
# - Rx total bytes & heartbeats since startup : 0.991311
# - Received packets & CPU Load(%) : 0.110403
# - Rx total bytes & CPU Load(%) : -0.321554
# - Heartbeat since startup & CPU Load(%) : -0.284210
# - Tx speed & CPU Load(%) : 0.399895

# %% [markdown]
# ##### 6. Building Histograms of some Important continous variables

# %% [markdown]
# ##### a) Histogram on Tx speed

# %%
plt.hist(drone_diag['Tx speed'],3)
plt.show()

# %% [markdown]
# ##### b) Histogram on Rx speed

# %%
plt.hist(drone_diag['Rx speed'],3)
plt.show()

# %% [markdown]
# ##### c) Histogram for EPV (m)

# %%
plt.hist(drone_diag['EPV (m)'], 5)
plt.show()

# %% [markdown]
# ##### d) Histogram for Satellites visible

# %%
plt.hist(drone_diag['Satellites visible'], 5)
plt.show()

# %% [markdown]
# ##### e) Histogram for Hearbeats since startup

# %%
plt.hist(drone_diag['Heartbeats since startup'], 5)
plt.show()

# %% [markdown]
# ##### f) Histogram for Tx total bytes

# %%
plt.hist(drone_diag['Tx total bytes'], 5)
plt.show()

# %% [markdown]
# ##### g) Histogram for Rx total bytes

# %%
plt.hist(drone_diag['Rx total bytes'], 5)
plt.show()

# %% [markdown]
# ##### h) Histogram for CPU Load (%)

# %%
plt.hist(drone_diag['CPU Load (%)'], 5)
plt.show()
